# %% [markdown]
# # Batch ATS superframe processing and visualization
#
# This notebook imports all `.ats` files in one folder and applies the same style of processing/visualization as `flir_ats_superframing_clean_v2`, but **only on reconstructed superframes**.
#
# Important differences from the older notebook:
#
# - no raw preset 0 / preset 1 processing;
# - no manual HDR-like merge;
# - no exported `.npz` files;
# - all statistics and plots are computed from `read_ats_file(..., read_mode="superframe")`.

# %% [markdown]
# ## 1. User settings
#
# Edit these paths before running the notebook.

# %%
from pathlib import Path

# Folder containing your .ats files
ATS_FOLDER = Path('/Volumes/Extreme SSD/GlobalAM-Dataset FINAL/ATS build 1 - without presintering')
#ATS_FOLDER = Path('/Volumes/Extreme SSD/GlobalAM-Dataset FINAL/ATS build 2 - with presintering')

# Optional: process only the first N files while testing. Use None for all files.
MAX_FILES = None

# Object emissivity passed to the ATS reader
EMISSIVITY = 1.0

# Optional maximum number of superframes to read per video. Use None for all.
MAX_FRAMES_PER_VIDEO = None

# Optional selected frame for image visualization below; 1 means first superframe.
SELECTED_SUPERFRAME_NUMBER = 100

# Optional crop coordinates for crop visualization: frames are indexed as [y, x]
Y_MIN, Y_MAX = 300, 400
X_MIN, X_MAX = 150, 250

# %% [markdown]
# ## 2. Imports
#
# This cell imports the installed `flir_ats_tools` package. If it fails, install the repository with `python -m pip install -e .`.

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from flir_ats_tools.utilities import inspect_ats_file, read_ats_file

print('Imported ATS utilities from: flir_ats_tools.utilities')
print(f'ATS folder: {ATS_FOLDER}')
# Out:
# Imported ATS utilities from: flir_ats_tools.utilities
# ATS folder: /Volumes/Extreme SSD/GlobalAM-Dataset FINAL/ATS build 1 - without presintering

# %% [markdown]
# ## 3. Find `.ats` files

# %%
ATS_FOLDER = ATS_FOLDER.expanduser().resolve()

ats_files = sorted([
    f for f in ATS_FOLDER.glob('*.ats')
    if not f.name.startswith('._')
])

if MAX_FILES is not None:
    ats_files = ats_files[:MAX_FILES]

print(f'Found {len(ats_files)} ATS files')
for f in ats_files:
    print(' -', f.name)

if not ats_files:
    raise FileNotFoundError(f'No .ats files found in {ATS_FOLDER}')
# Out:
# Found 14 ATS files
#  - GlobalAM_without presintering_layer100.ats
#  - GlobalAM_without presintering_layer110.ats
#  - GlobalAM_without presintering_layer120.ats
#  - GlobalAM_without presintering_layer130.ats
#  - GlobalAM_without presintering_layer140.ats
#  - GlobalAM_without presintering_layer150.ats
#  - GlobalAM_without presintering_layer154.ats
#  - GlobalAM_without presintering_layer30.ats
#  - GlobalAM_without presintering_layer40.ats
#  - GlobalAM_without presintering_layer50.ats
#  - GlobalAM_without presintering_layer60.ats
#  - GlobalAM_without presintering_layer70.ats
#  - GlobalAM_without presintering_layer81.ats
#  - GlobalAM_without presintering_layer90.ats

# %% [markdown]
# ## 4. Helper functions
#
# `load_superframes()` is the key point: it reads each video using `read_mode="superframe"`, so every subsequent computation uses the merged superframing frames only.

# %%
def get_layer_number(name):
    """Extract layer number from filenames containing e.g. 'layer40'."""
    match = re.search(r'layer(\d+)', name, flags=re.IGNORECASE)
    return int(match.group(1)) if match else float('inf')


def load_superframes(ats_path: Path, emissivity: float = 1.0, max_frames=None):
    """Load one ATS file as reconstructed superframes only."""
    object_parameters = {'emissivity': emissivity}

    inspection = inspect_ats_file(
        str(ats_path),
        object_parameter_updates=object_parameters,
    )

    if not inspection.is_superframe:
        raise ValueError(f'{ats_path.name} is not reported as a superframing ATS file.')

    ats_data = read_ats_file(
        str(ats_path),
        read_mode='superframe',
        object_parameter_updates=object_parameters,
        inspection=inspection,
        max_frames=max_frames,
    )

    return ats_data


def compute_superframe_statistics(frames: np.ndarray) -> pd.DataFrame:
    """Compute frame-wise statistics from a superframe stack shaped (n_frames, height, width)."""
    flat = frames.reshape(frames.shape[0], -1)

    stats = pd.DataFrame({
        'superframe_id': np.arange(1, frames.shape[0] + 1),
        'min': np.nanmin(flat, axis=1),
        'max': np.nanmax(flat, axis=1),
        'mean': np.nanmean(flat, axis=1),
        'std': np.nanstd(flat, axis=1),
        'p05': np.nanpercentile(flat, 5, axis=1),
        'p95': np.nanpercentile(flat, 95, axis=1),
    })
    stats['range'] = stats['max'] - stats['min']
    return stats

# %% [markdown]
# ## 5. Read all videos as superframes and compute statistics
#
# This creates:
#
# - `all_results`: dictionary with one entry per ATS video;
# - `summary_table`: compact table with one row per video.

# %%
all_results = {}
summary_rows = []

for ats_path in ats_files:
    print(f'Processing: {ats_path.name}')

    ats_data = load_superframes(
        ats_path,
        emissivity=EMISSIVITY,
        max_frames=MAX_FRAMES_PER_VIDEO,
    )

    frames = ats_data.frames
    stats = compute_superframe_statistics(frames)

    video_name = ats_path.stem
    all_results[video_name] = {
        'path': ats_path,
        'ats_data': ats_data,
        'frames': frames,
        'stats': stats,
    }

    summary_rows.append({
        'video': video_name,
        'n_superframes': frames.shape[0],
        'height': frames.shape[1],
        'width': frames.shape[2],
        'global_min': np.nanmin(frames),
        'global_mean': np.nanmean(frames),
        'global_max': np.nanmax(frames),
        'mean_of_frame_means': stats['mean'].mean(),
        'mean_of_frame_stds': stats['std'].mean(),
    })

summary_table = pd.DataFrame(summary_rows).sort_values(
    by='video',
    key=lambda s: s.map(get_layer_number),
).reset_index(drop=True)

print('Done.')
display(summary_table)
# Out:
# Processing: GlobalAM_without presintering_layer100.ats
# reading frame 6199 of 6200
# Processing: GlobalAM_without presintering_layer110.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer120.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer130.ats
# reading frame 6199 of 6200
# Processing: GlobalAM_without presintering_layer140.ats
# reading frame 6199 of 6200
# Processing: GlobalAM_without presintering_layer150.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer154.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer30.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer40.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer50.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer60.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer70.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer81.ats
# reading frame 6200 of 6200
# Processing: GlobalAM_without presintering_layer90.ats
# reading frame 6199 of 6200
# Done.
#                                      video  n_superframes  height  width  \
# 0    GlobalAM_without presintering_layer30           3100     404    384
# 1    GlobalAM_without presintering_layer40           3100     404    384
# 2    GlobalAM_without presintering_layer50           3100     404    384
# 3    GlobalAM_without presintering_layer60           3100     404    384
# 4    GlobalAM_without presintering_layer70           3100     404    384
# 5    GlobalAM_without presintering_layer81           3100     404    384
# 6    GlobalAM_without presintering_layer90           3100     404    384
# 7   GlobalAM_without presintering_layer100           3100     404    384
# 8   GlobalAM_without presintering_layer110           3100     404    384
# 9   GlobalAM_without presintering_layer120           3100     404    384
# 10  GlobalAM_without presintering_layer130           3100     404    384
# 11  GlobalAM_without presintering_layer140           3100     404    384
# 12  GlobalAM_without presintering_layer150           3100     404    384
# 13  GlobalAM_without presintering_layer154           3100     404    384
#
#     global_min  global_mean  global_max  mean_of_frame_means  \
# 0    302.57724   309.958130  640.644409           309.957336
# 1    302.57724   309.862610  640.644409           309.847076
# 2    302.57724   310.081299  640.644409           310.075592
# 3    302.57724   310.113281  640.644409           310.112915
# 4    302.57724   310.161377  640.644409           310.159302
# 5    302.57724   310.157684  640.644409           310.172424
# 6    302.57724   310.140442  640.644409           310.156921
# 7    302.57724   310.123260  640.644409           310.145477
# 8    302.57724   310.084656  640.644409           310.113190
# 9    302.57724   310.063538  640.644409           310.083740
# 10   302.57724   310.094116  640.644409           310.105865
# 11   302.57724   310.115692  640.644409           310.106018
# 12   302.57724   310.117035  640.644409           310.103943
# 13   302.57724   310.106995  640.644409           310.093781
#
#     mean_of_frame_stds
# 0            10.310308
# 1             9.540274
# 2             9.590654
# 3             9.393837
# 4             9.197686
# 5             8.805386
# 6             8.759956
# 7             8.513033
# 8             8.242903
# 9             7.984373
# 10            7.989752
# 11            7.820716
# 12            7.597359
# 13            7.620898

# %% [markdown]
# ## 6. Three-panel plot: min, max, and mean intensity of superframes
#
# Each curve corresponds to one `.ats` video. All values are computed on reconstructed superframes only.

# %%
sorted_items = sorted(
    all_results.items(),
    key=lambda item: get_layer_number(item[0])
)

fig, axes = plt.subplots(3, 1, figsize=(12, 12), sharex=True)

plot_specs = [
    ('min', 'Minimum intensity'),
    ('max', 'Maximum intensity'),
    ('mean', 'Mean intensity'),
]

for ax, (column, title) in zip(axes, plot_specs):
    for video_name, results in sorted_items:
        stats = results['stats']
        layer_id = get_layer_number(video_name)
        label = f'layer_{layer_id}' if np.isfinite(layer_id) else video_name
        ax.plot(stats['superframe_id'], stats[column], label=label, linewidth=0.8)

    ax.set_title(f'Superframe - {title}')
    ax.set_ylabel(title)
    ax.grid(True)

# 👉 set ONLY for the third panel (mean)
axes[2].set_ylim(306, 312)

axes[-1].set_xlabel('Superframe order')
axes[0].legend(fontsize=8, loc='best', ncol=2)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from pathlib import Path

# Your target folder
CSV_OUTPUT_DIR = Path('/Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper')

# Create folder if it doesn't exist
CSV_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

for video_name, results in sorted_items:
    stats = results["stats"]

    df = pd.DataFrame({
        "superframe_id": stats["superframe_id"],
        "min_intensity": stats["min"],
        "max_intensity": stats["max"],
        "mean_intensity": stats["mean"],
    })

    # Clean filename (remove problematic characters)
    safe_name = Path(video_name).stem.replace(" ", "_")

    output_path = CSV_OUTPUT_DIR / f"{safe_name}_intensity_statistics.csv"

    df.to_csv(output_path, index=False)

    print(f"Saved: {output_path}")
# Out:
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer30_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer40_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer50_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer60_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer70_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer81_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer90_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer100_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer110_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer120_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer130_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer140_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer150_intensity_statistics.csv
# Saved: /Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper/GlobalAM_without_presintering_layer154_intensity_statistics.csv

# %% [markdown]
# ## 7. Additional plots transferred from the old notebook, but on superframes
#
# The old notebook plotted standard deviation and mean separately for low/high subframes. Here there is only one merged superframe sequence, so the analogous plot is `std` and `mean` of the reconstructed superframes.

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

for video_name, results in sorted_items:
    stats = results['stats']
    layer_id = get_layer_number(video_name)
    label = f'layer_{layer_id}' if np.isfinite(layer_id) else video_name

    axes[0].plot(stats['superframe_id'], stats['std'], label=label, linewidth=0.8)
    axes[1].plot(stats['superframe_id'], stats['mean'], label=label, linewidth=0.8)

axes[0].set_title('Superframe - standard deviation of intensity')
axes[1].set_title('Superframe - mean intensity')

axes[0].set_ylabel('Standard deviation')
axes[1].set_ylabel('Mean')
axes[1].set_xlabel('Superframe order')

for ax in axes:
    ax.grid(True)

axes[0].legend(fontsize=8, loc='best', ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Mean with 5–95 percentile band for one selected video
#
# This reproduces the mean + percentile-band logic, but using the merged superframe image at each time step.

# %%
# Select the first video by default. Change SELECTED_VIDEO_NAME to a key in all_results if needed.
SELECTED_VIDEO_NAME = sorted_items[0][0]

stats = all_results[SELECTED_VIDEO_NAME]['stats']

plt.figure(figsize=(10, 5))
plt.plot(stats['superframe_id'], stats['mean'], linewidth=1.5, label='Mean')
plt.fill_between(
    stats['superframe_id'],
    stats['p05'],
    stats['p95'],
    alpha=0.3,
    label='5–95 percentile',
)

plt.xlabel('Superframe order')
plt.ylabel('Intensity')
plt.title(f'Superframe intensity over time - {SELECTED_VIDEO_NAME}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Visualize one reconstructed superframe
#
# This replaces the old side-by-side raw subframe 0 / raw subframe 1 / manual merge plot. Here the displayed frame is directly the reconstructed superframe returned by the reader.

# %%
SELECTED_VIDEO_NAME = sorted_items[1][0] # LAYER 40
frames = all_results[SELECTED_VIDEO_NAME]['frames']

SELECTED_SUPERFRAME_NUMBERS = [689, 762, 837, 913, 988, 1064, 1139, 1215]  # WITHOUT PRESINTERING
#SELECTED_SUPERFRAME_NUMBERS = [779, 826, 949, 1034, 1119, 1204, 1289, 1375] #WITH PRESINTERING

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.ravel()

for ax, superframe_number in zip(axes, SELECTED_SUPERFRAME_NUMBERS):

    frame_index = superframe_number - 1

    if frame_index < 0 or frame_index >= frames.shape[0]:
        raise IndexError(
            f'SELECTED_SUPERFRAME_NUMBER={superframe_number} is outside '
            f'the available range 1..{frames.shape[0]} for {SELECTED_VIDEO_NAME}'
        )

    frame = frames[frame_index]

    im = ax.imshow(frame, cmap='inferno', vmin = 310, vmax=400)
    ax.set_title(f'Superframe {superframe_number}', fontsize=10)
    ax.axis('off')

# 👉 Increase vertical spacing
fig.subplots_adjust(hspace=0.08, wspace=0.01)

# 👉 Leave room on the right for colorbar
fig.subplots_adjust(right=0.90)

# 👉 Create a dedicated axis for colorbar (outside panels)
cbar_ax = fig.add_axes([0.90, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.set_label('Intensity')

fig.suptitle(f'{SELECTED_VIDEO_NAME} - reconstructed superframes', fontsize=14)

plt.show()

# %% [markdown]
# ## 10. Violinplots of layer 40 within the ROIs (from binary mask)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
from scipy import ndimage

# -----------------------------
# Inputs
# -----------------------------
SELECTED_VIDEO_NAME = sorted_items[1][0]  # LAYER 40
frames = all_results[SELECTED_VIDEO_NAME]["frames"]   # shape: (n_superframes, rows, cols)

MASK_PATH = Path('/Volumes/Extreme SSD/GlobalAM-Dataset FINAL/Mask_build 1 - without_presintering.png')  # WITHOUT PRESINTERING
#MASK_PATH = Path('/Volumes/Extreme SSD/GlobalAM-Dataset FINAL/Mask_build 2 - with_presintering.png')  # WITH PRESINTERING

# Rows = [start_superframe, end_superframe], 1-based and inclusive     #WITHOUT PRESINTERING
X = np.array([
    [21, 663],
    [686, 1290],
    [1311, 1778],
    [1798, 2170],
    [2194, 2428],
    [2461, 2682],
    [2706, 2879],
    [2893, 3025],
])

# Rows = [start_superframe, end_superframe], 1-based and inclusive     #WITH PRESINTERING
# X = np.array([
#     [41, 716],
#     [779, 1460],
#     [1526, 2210],
#     [2254, 2927],
#     [2966, 3232],
#     [3282, 3550],
#     [3661, 3936],
#     [4023, 4294],
# ])

# -----------------------------
# Load grayscale mask
# -----------------------------
mask_img = Image.open(MASK_PATH).convert("L")
mask_gray = np.array(mask_img).astype(float)

# Normalize to 0-1 if image is 0-255
if mask_gray.max() > 1:
    mask_gray = mask_gray / 255.0

# Background is white ~1; foreground components are darker
foreground = mask_gray < 0.99

# Optional sanity check
plt.figure(figsize=(5, 5))
plt.imshow(foreground, cmap="gray")
plt.title("Detected foreground components")
plt.axis("off")
plt.show()

# -----------------------------
# Label connected components
# -----------------------------
labeled_mask, n_components = ndimage.label(foreground)

print(f"Detected connected components: {n_components}")

if n_components < X.shape[0]:
    raise ValueError(
        f"Detected only {n_components} connected components, "
        f"but X contains {X.shape[0]} frame ranges."
    )

if labeled_mask.shape != frames.shape[1:]:
    raise ValueError(
        f"Mask shape {labeled_mask.shape} does not match frame shape {frames.shape[1:]}."
    )

# -----------------------------
# Order components by mask grayscale intensity
# lowest intensity = first row of X
# highest foreground intensity = last row of X
# -----------------------------
component_info = []

for comp_id in range(1, n_components + 1):
    comp_pixels = labeled_mask == comp_id
    mean_gray = np.mean(mask_gray[comp_pixels])
    component_info.append((comp_id, mean_gray))

component_info_sorted = sorted(component_info, key=lambda x: x[1])
ordered_component_ids = [comp_id for comp_id, _ in component_info_sorted]

print("\nComponent order based on mask grayscale intensity:")
for order, (comp_id, mean_gray) in enumerate(component_info_sorted, start=1):
    print(f"Order {order}: component {comp_id}, mean mask intensity = {mean_gray:.4f}")

# Use only as many components as rows in X
ordered_component_ids = ordered_component_ids[:X.shape[0]]

# -----------------------------
# Extract mean intensity per superframe inside each component
# -----------------------------
boxplot_data = []
boxplot_labels = []

for row_id, (start_sf, end_sf) in enumerate(X, start=1):

    comp_id = ordered_component_ids[row_id - 1]

    # Convert 1-based inclusive superframe numbers to Python slicing
    start_idx = start_sf - 1
    end_idx = end_sf

    if start_idx < 0 or end_idx > frames.shape[0]:
        raise IndexError(
            f"Range {start_sf}-{end_sf} is outside available superframes "
            f"1..{frames.shape[0]}"
        )

    frame_stack = frames[start_idx:end_idx]
    comp_pixels = labeled_mask == comp_id

    mean_intensity_per_frame = np.nanmean(frame_stack[:, comp_pixels], axis=1)

    boxplot_data.append(mean_intensity_per_frame)
    boxplot_labels.append(f"CC {comp_id}\nSF {start_sf}-{end_sf}")
    custom_labels = [
    "Sub.1 Part 1", "Sub.1 Part 2", "Sub.1 Part 3", "Sub.1 Part 4",
    "Sub.2 Part 1", "Sub.2 Part 2", "Sub.2 Part 3", "Sub.2 Part 4"
    ]

    print(
        f"X row {row_id}: superframes {start_sf}-{end_sf} "
        f"-> component {comp_id}, "
        f"n={len(mean_intensity_per_frame)} frames"
    )

# -----------------------------
# Violin plot
# -----------------------------
plt.figure(figsize=(11, 5))

# Violin plot
parts = plt.violinplot(
    boxplot_data,
    showmeans=False,
    showmedians=True,
    showextrema=False
)

# Optional styling
for pc in parts['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_alpha(0.4)

# Overlay points (jittered)
for i, data in enumerate(boxplot_data, start=1):
    x = np.random.normal(i, 0.04, size=len(data))  # small horizontal jitter
    plt.scatter(x, data, s=8, alpha=0.4, color='k')

# X ticks
plt.xticks(
    ticks=np.arange(1, len(boxplot_labels) + 1),
    labels=custom_labels
)

plt.xlabel("Sample")
plt.ylim(301, 493)
plt.ylabel("Mean intensity within ROI")
plt.title("Mean superframe intensity during laser exposure")
plt.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Detected connected components: 8
#
# Component order based on mask grayscale intensity:
# Order 1: component 8, mean mask intensity = 0.0431
# Order 2: component 6, mean mask intensity = 0.0471
# Order 3: component 7, mean mask intensity = 0.0510
# Order 4: component 5, mean mask intensity = 0.0549
# Order 5: component 4, mean mask intensity = 0.0824
# Order 6: component 2, mean mask intensity = 0.0863
# Order 7: component 3, mean mask intensity = 0.0902
# Order 8: component 1, mean mask intensity = 0.0941
# X row 1: superframes 41-716 -> component 8, n=676 frames
# X row 2: superframes 779-1460 -> component 6, n=682 frames
# X row 3: superframes 1526-2210 -> component 7, n=685 frames
# X row 4: superframes 2254-2927 -> component 5, n=674 frames
# X row 5: superframes 2966-3232 -> component 4, n=267 frames
# X row 6: superframes 3282-3550 -> component 2, n=269 frames
# X row 7: superframes 3661-3936 -> component 3, n=276 frames
# X row 8: superframes 4023-4294 -> component 1, n=272 frames

# %% [markdown]
# # PANOS CODE for additional visualization

# %%
from pathlib import Path
import re

import numpy as np
import pandas as pd
from scipy.stats import mannwhitneyu
import seaborn as sns
import matplotlib.pyplot as plt

# =========================================================
# FOLDER CONTAINING CSV FILES
# =========================================================

DATA_FOLDER = Path(
    '/Users/marcograsso/Library/CloudStorage/Dropbox/MUSP_tutta/articoli/2025 papers/GlobalAM_dataset paper'
)

# =========================================================
# FUNCTION TO LOAD MAX AND MEAN MATRICES FROM CSV FILES
# =========================================================

def load_statistics(pattern):

    files = sorted(
        DATA_FOLDER.glob(pattern),
        key=lambda x: int(re.search(r'layer(\d+)', x.name).group(1))
    )

    if len(files) == 0:
        raise FileNotFoundError(f'No files found with pattern: {pattern}')

    max_all_layers = []
    mean_all_layers = []

    for file in files:

        print(f'Loading: {file.name}')

        df = pd.read_csv(file)

        # Clean column names
        df.columns = df.columns.str.strip().str.lower()

        # Extract max and mean intensity
        max_values = df['max_intensity'].to_numpy(dtype=float)
        mean_values = df['mean_intensity'].to_numpy(dtype=float)

        max_all_layers.append(max_values)
        mean_all_layers.append(mean_values)

    # Convert lists to matrices
    # Rows = frames, columns = layers
    max_len = max(len(x) for x in max_all_layers)

    max_matrix = np.full((max_len, len(max_all_layers)), np.nan)
    mean_matrix = np.full((max_len, len(mean_all_layers)), np.nan)

    for j in range(len(max_all_layers)):
        max_matrix[:len(max_all_layers[j]), j] = max_all_layers[j]
        mean_matrix[:len(mean_all_layers[j]), j] = mean_all_layers[j]

    return max_matrix, mean_matrix

# =========================================================
# LOAD WITHOUT PRE-SINTERING
# =========================================================

WithOutMax, WithOutMean = load_statistics(
    'GlobalAM_without_presintering_layer*_intensity_statistics.csv'
)

# =========================================================
# LOAD WITH PRE-SINTERING
# =========================================================

WithMax, WithMean = load_statistics(
    'GlobalAM-contour_pre-sintering-layer*_intensity_statistics.csv'
)

# =========================================================
# CONVERT MATRICES TO DATAFRAMES
# =========================================================

df_without_max = pd.DataFrame({
    'value': np.ravel(WithOutMax),
    'variable': 'Max',
    'build': 'Without'
})

df_with_max = pd.DataFrame({
    'value': np.ravel(WithMax),
    'variable': 'Max',
    'build': 'With'
})

df_without_mean = pd.DataFrame({
    'value': np.ravel(WithOutMean),
    'variable': 'Mean',
    'build': 'Without'
})

df_with_mean = pd.DataFrame({
    'value': np.ravel(WithMean),
    'variable': 'Mean',
    'build': 'With'
})

# =========================================================
# MERGE ALL DATA
# =========================================================

df_dist = pd.concat(
    [
        df_without_max,
        df_with_max,
        df_without_mean,
        df_with_mean
    ],
    ignore_index=True
)

# Remove NaNs introduced by padding
df_dist = df_dist.dropna()

df_dist['variable'] = pd.Categorical(
    df_dist['variable'],
    categories=['Max', 'Mean'],
    ordered=True
)

df_dist['build'] = pd.Categorical(
    df_dist['build'],
    categories=['Without', 'With'],
    ordered=True
)

# =========================================================
# MANN-WHITNEY U TEST
# Equivalent to Wilcoxon rank-sum test for independent samples
# =========================================================

pvals = []

for var in ['Max', 'Mean']:

    data_without = df_dist[
        (df_dist['variable'] == var) &
        (df_dist['build'] == 'Without')
    ]['value']

    data_with = df_dist[
        (df_dist['variable'] == var) &
        (df_dist['build'] == 'With')
    ]['value']

    stat, p = mannwhitneyu(
        data_without,
        data_with,
        alternative='two-sided'
    )

    pvals.append({
        'variable': var,
        'U_statistic': stat,
        'p_value': p
    })

pvals = pd.DataFrame(pvals)

print('\nMann-Whitney / Wilcoxon rank-sum test results:')
print(pvals)

# =========================================================
# PLOT
# =========================================================

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

variables = ['Max', 'Mean']

titles = [
    'Max intensity within whole frame (all layers)',
    'Mean intensity within whole frame (all layers)'
]

xlabels = [
    'Without pre-sintering',
    'With pre-sintering'
]

for ax, var, title in zip(axes, variables, titles):

    subset = df_dist[df_dist['variable'] == var]

    # -----------------------------------------------------
    # VIOLIN PLOT
    # -----------------------------------------------------

    sns.violinplot(
        data=subset,
        x='build',
        y='value',
        inner=None,
        cut=0,
        linewidth=1,
        ax=ax
    )

    # -----------------------------------------------------
    # BOXPLOT
    # -----------------------------------------------------

    sns.boxplot(
        data=subset,
        x='build',
        y='value',
        width=0.18,
        showfliers=True,
        showcaps=True,

        boxprops={
            'facecolor': 'white',
            'edgecolor': 'black',
            'linewidth': 1.5,
            'zorder': 10
        },

        medianprops={
            'color': 'red',
            'linewidth': 2.5,
            'zorder': 11
        },

        whiskerprops={
            'color': 'black',
            'linewidth': 1.5,
            'zorder': 10
        },

        capprops={
            'color': 'black',
            'linewidth': 1.5,
            'zorder': 10
        },

        flierprops={
            'marker': 'o',
            'markerfacecolor': 'black',
            'markeredgecolor': 'black',
            'markersize': 3,
            'alpha': 0.5
        },

        ax=ax
    )

    # -----------------------------------------------------
    # TITLES AND LABELS
    # -----------------------------------------------------

    ax.set_title(title)

    ax.set_xlabel('')
    ax.set_ylabel('Intensity')

    ax.set_xticklabels(xlabels)

plt.tight_layout()
plt.show()
# Out:
# Loading: GlobalAM_without_presintering_layer30_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer40_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer50_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer60_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer70_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer81_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer90_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer100_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer110_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer120_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer130_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer140_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer150_intensity_statistics.csv
# Loading: GlobalAM_without_presintering_layer154_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer28_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer40_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer50_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer60_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer70_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer80_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer90_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer100_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer111_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer119_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer131_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer141_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer150_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer160_intensity_statistics.csv
# Loading: GlobalAM-contour_pre-sintering-layer166_intensity_statistics.csv
#
# Mann-Whitney / Wilcoxon rank-sum test results:
#   variable   U_statistic  p_value
# 0      Max  1.821573e+09      0.0
# 1     Mean  2.864574e+09      0.0
# /opt/anaconda3/envs/qda-environment_MAC/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/anaconda3/envs/qda-environment_MAC/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/anaconda3/envs/qda-environment_MAC/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/anaconda3/envs/qda-environment_MAC/lib/python3.12/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
